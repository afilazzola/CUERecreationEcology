# %%
import populartimes
import json
import pandas as pd
import os

from tqdm import tqdm

# %%
api_key = "AIzaSyAKSzjYU6hrokqatr6HNaADbAjqGESL64I"

# %%
belfountain = populartimes.get_id(api_key=api_key, place_id="ChIJH5i_lbQIK4gRJkH8gOJps_I")

# %%
belfountain
# Out:
# {'id': 'ChIJH5i_lbQIK4gRJkH8gOJps_I',
#  'name': 'Belfountain Conservation Area',
#  'address': '10 Credit Park St, Belfountain, ON L7K 0E5, Canada',
#  'types': ['park', 'tourist_attraction', 'point_of_interest', 'establishment'],
#  'coordinates': {'lat': 43.7942469, 'lng': -80.0128392},
#  'rating': 4.5,
#  'rating_n': 2183,
#  'international_phone_number': '+1 800-367-0890'}

# %%
islandLake = populartimes.get_id(api_key=api_key, place_id="ChIJd8UnymYAK4gRc6-GeCf43CQ")
islandLake
# Out:
# {'id': 'ChIJd8UnymYAK4gRc6-GeCf43CQ',
#  'name': 'Island Lake Conservation Area',
#  'address': '673067 Hurontario St, Orangeville, ON L9W 2Y9, Canada',
#  'types': ['park', 'tourist_attraction', 'point_of_interest', 'establishment'],
#  'coordinates': {'lat': 43.93324019999999, 'lng': -80.0800553},
#  'rating': 4.6,
#  'rating_n': 1387,
#  'international_phone_number': '+1 800-367-0890',
#  'current_popularity': 3,
#  'populartimes': [{'name': 'Monday',
#    'data': [0,
#     0,
#     0,
#     0,
#     0,
#     0,
#     0,
#     0,
#     5,
#     8,
#     11,
#     14,
#     16,
#     16,
#     15,
#     13,
#     10,
#     7,
#     5,
#     3,
#     0,
#     0,
#     0,
#     0]},
#   {'name': 'Tuesday',
#    'data': [0,
#     0,
#     0,
#     0,
#     0,
#     0,
#     0,
#     0,
#     2,
#     5,
#     10,
#     13,
#     13,
#     13,
#     14,
#     16,
#     15,
#     12,
#     7,
#     3,
#     0,
#     0,
#     0,
#     0]},
#   {'name': 'Wednesday',
#    'data': [0,
# ...

# %% [markdown]
# ## For loop

# %%
df = pd.read_csv("ListOfPlaces.csv")
df.head()
# Out:
#     CA          Property             Google Places ID
# 0  CVC    Island Lake CA  ChIJd8UnymYAK4gRc6-GeCf43CQ
# 1  CVC      Limehouse CA  ChIJzSme5BhzK4gRTMBFac8Z4PU
# 2  CVC     Meadowvale CA  ChIJtXWdUgJAK4gRZgqeISAdMAA
# 3  CVC  Rattray Marsh CA  ChIJa4vlaFJEK4gRXfylGnDlCI8
# 4  CVC   Silver Creek CA  ChIJrXS51N8MK4gR4QZ8g9_u9Ww

# %%
for property_name, place_id in zip(df['Property'], df['Google Places ID']):
    property_populartimes = populartimes.get_id(api_key = api_key, 
                                                place_id = place_id)
    
    file_name = f'data/populartimes/JSON/{property_name}.json'
    open(file_name, "x")
    with open(file_name, 'w') as f:
        json.dump(islandLake, f)
        f.close()
